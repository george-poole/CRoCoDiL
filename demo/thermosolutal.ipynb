# %%
from lucifex.fdm import AB2, CN
from lucifex.sim import integrate, postprocess_grids
from lucifex.utils import grid, spacetime_grid
from lucifex.viz import plot_colormap, create_animation
from lucifex.io import write

from co2_dissolution_pkg.sim import thermosolutal_rectangle


STORE = 1
WRITE = None

simulation = thermosolutal_rectangle(store_step=STORE, write_step=WRITE)(
    Nx=64,
    Ny=64,
    Ra=4e2,
    Da=4e2,
    epsilon=1e-2,

)

n_stop = 200
dt_init = 1e-6
n_init = 5
# integrate(simulation, n_stop=n_stop, dt_init=dt_init, n_init=n_init)
