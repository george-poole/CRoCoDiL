# %% [markdown]
# # Parameter space
#
# The following notebooks explore the effect of varying the parameters $Ra$, $Da$, $s_r$ compared to a canonical reference system of aspect ratio $\mathcal{A}=2$ chosen to have the parameter values
#
# $$
# \begin{align*}
# Ra &= 1000 \\
# Da &= 100 \\
# \varepsilon &= 0.01 \\
# \zeta_0 &= 0.9 \\
# s_r &= 0.2 \\
# c_r &= 0.0 \\
# \end{align*}
# $$

# %%
from crocodil.dns.system_a import SYSTEM_A_REFERENCE

print(SYSTEM_A_REFERENCE)
# Out:
# {'Ra': 1000.0, 'Da': 100.0, 'epsilon': 0.01, 'zeta0': 0.9, 'sr': 0.2, 'cr': 0.0, 'aspect': 2.0}
